# %% [markdown]
# # Part 6: Final Challenge - Putting it all together
#
# Through-out this workshop, we've covered many topics including:
#
# *   **Object-Oriented Programming**
#  * Member Variables (Instance vs Class Variables)
#  * Member Methods (Instance vs Class vs Static Methods)
#  * The `@property` decorator
#  * Special (Magic) methods
#  * Inheritance
#  * Bonus: Private members, getters/setters, and the `@setter` decorator
# *   **Exception Handling**
#  * Try-Except Blocks
#  * Creating and Raising custom exceptions
# *   **Recursion**
# *   **Basic File Handling (Reading/Writing)**
#  * Opening and closing files
#  * Reading/writing text files
#  * Reading CSV/TSV files
#  * Reading JSON files
#
# Now you will put it all together in a larger challenge.
#
# ---
# You will be working with data from STRING, a biological database of known and predicted protein-protein interactions.

# %% [markdown]
# ## **Preparation**
#
# Human protein interaction data was downloaded and pre-processed from the STRING database website. Download the preprocessed data file from Github here.

# %% [markdown]
# ### Pre-processing details
#
# * STRING database contents for human proteins: https://string-db.org/cgi/download.pl?species_text=Homo+sapiens
# * Raw data files used: 9606.protein.links.detailed.v11.0.txt.gz (110.1 Mb) and 9606.protein.info.v11.0.txt.gz (1.9 Mb)
# * Protein interactions with filtered to include only those with a total score >= 700 (only evidence sub scores from experiments, fusion proteins, and curated databases were included)
# * STRING protein IDs were mapped to their common name (alias) when possible
# * Results were finally exported to a table (.tsv file), where each row corresponds to one protein-protein interaction. The file contains three (3) columns: the first two contain the protein names, and the third is the total interaction (computed as described above).
#
# **Future Challenge: After the workshop, have a go at performing this pre-processing yourself!**

# %% [markdown]
# ## **Objective**
#
# Write a Python program that will read from the parsed tsv file, model this data, and make queries. Once you write your program, you should be able to do the following:
#
# * Given a protein name, list all the other proteins that interact with it
# * Retrieve a list of all the proteins in the network, sorted by the number of interactions

# %% [markdown]
# ### Example Questions:
# * Q: What are all the proteins reported to interact with `FOXP3` in the dataset?
# * Q: Which 10 proteins in the network have the greatest number of interacting partners

# %% [markdown]
# ---
#
# ### **TIPS**
# * Take a few minutes to look at the data fles and develop a plan before typing any code
# * Keep your code organized for easy debugging (and reuse!)
# * Use classes to organize your code (e.g. creating a `Protein` class and `GeneNetwork` class). What kind of methods/attributes might they have?
# * During the live session, you are welcome to converse and brainstorm with others in the chat
# * Think about what other questions you could ask of the data, and what functionality you could add to your program that would help you answer those questions. If you have extra time, go for it!
#
# After the workshop, you can continue the conversation on Slack with both the instructor (me) and your fellow collegues.
